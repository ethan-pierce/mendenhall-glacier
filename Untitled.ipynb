# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
base_flux = np.loadtxt('./experiments/static-effective-pressure/outputs/dispersed_flux_Pw_95_pct.txt')

for i in [60, 65, 70, 75, 80, 85, 90, 95]:
    flux = np.loadtxt('./experiments/static-effective-pressure/outputs/dispersed_flux_Pw_' + str(i) + '_pct.txt')
    plt.plot(flux)
    
plt.show()

# %%
for i in [60, 65, 70, 75, 80, 85, 90, 95]:
    flux = np.loadtxt('./experiments/static-effective-pressure/outputs/fringe_flux_Pw_' + str(i) + '_pct.txt')
    plt.plot(flux)
    
plt.show()
